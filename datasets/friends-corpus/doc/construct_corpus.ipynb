# %%
import os
os.chdir('../json')

# %%
import json

# %%
from convokit import Corpus, Utterance, User

# %%
with open('friends_season_01.json', 'r') as f:
    s01_corpus_json = json.load(f)

# %%
s01_corpus_json['season_id']
# Out:
# 's01'

# %%
def convert_json_to_utterances(season_json):
    retval = []
    season_id = season_json['season_id']
    for episode in season_json['episodes']:
        episode_id = episode['episode_id']
        for scene in episode['scenes']:
            scene_id = scene['scene_id']
            reply_to = None
            for i, utt in enumerate(scene['utterances']):
                if i == 0:
                    reply_to = None
                    root = utt['utterance_id']
                else:
                    reply_to = utt_id # previous utt_id
                utt_id = utt['utterance_id']
                speakers = utt['speakers'][0] if len(utt['speakers']) > 0 else None
                transcript = utt['transcript']
                tokens = utt['tokens']
                transcript_note = utt['transcript_with_note']
                tokens_with_note = utt['tokens_with_note']
                character_entities = utt['character_entities']
                retval.append(Utterance(id=utt_id, 
                                        user=User(name=speakers),
                                        root=root,
                                        reply_to=reply_to,
                                        text=transcript,
                                        meta={
                                            'tokens': tokens,
                                            'transcript_with_note': transcript_note,
                                            'tokens_with_note': tokens_with_note,
                                            'character_entities': character_entities
                                        }
                                       ))
    return retval

# %%
utts = convert_json_to_utterances(s01_corpus_json)

# %%
s01_corpus = Corpus(utterances=convert_json_to_utterances(s01_corpus_json))

# %%
s01_corpus.print_summary_stats()
# Out:
# Number of Users: 108
# Number of Utterances: 6626
# Number of Conversations: 326

# %%
list(s01_corpus.get_user('Ross Geller').iter_utterances())
# Out:
# [Utterance({'id': 's01_e01_c01_u021', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c01_u001', 'reply_to': 's01_e01_c01_u020', 'timestamp': None, 'text': 'Hi.', 'meta': {'tokens': [['Hi', '.']], 'transcript_with_note': '(mortified) Hi.', 'tokens_with_note': [['(', 'mortified', ')', 'Hi', '.']], 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e01_c01_u024', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c01_u001', 'reply_to': 's01_e01_c01_u023', 'timestamp': None, 'text': 'I just feel like someone reached down my throat, grabbed my small intestine, pulled it out of my mouth and tied it around my neck...', 'meta': {'tokens': [['I', 'just', 'feel', 'like', 'someone', 'reached', 'down', 'my', 'throat', ',', 'grabbed', 'my', 'small', 'intestine', ',', 'pulled', 'it', 'out', 'of', 'my', 'mouth', 'and', 'tied', 'it', 'around', 'my', 'neck', '...']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller'], [7, 8, 'Ross Geller'], [11, 12, 'Ross Geller'], [19, 20, 'Ross Geller'], [25, 26, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c01_u029', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c01_u001', 'reply_to': 's01_e01_c01_u028', 'timestamp': None, 'text': 'Thanks.', 'meta': {'tokens': [['Thanks', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e01_c01_u031', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c01_u001', 'reply_to': 's01_e01_c01_u030', 'timestamp': None, 'text': "No, no don't! Stop cleansing my aura! No, just leave my aura alone, okay?", 'meta': {'tokens': [['No', ',', 'no', 'do', "n't", '!'], ['Stop', 'cleansing', 'my', 'aura', '!'], ['No', ',', 'just', 'leave', 'my', 'aura', 'alone', ',', 'okay', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [[2, 3, 'Ross Geller']], [[4, 5, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c01_u033', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c01_u001', 'reply_to': 's01_e01_c01_u032', 'timestamp': None, 'text': "I'll be fine, alright? Really, everyone. I hope she'll be very happy.", 'meta': {'tokens': [['I', "'ll", 'be', 'fine', ',', 'alright', '?'], ['Really', ',', 'everyone', '.'], ['I', 'hope', 'she', "'ll", 'be', 'very', 'happy', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller']], [], [[0, 1, 'Ross Geller'], [2, 3, 'Carol Willick']]]}}),
#  Utterance({'id': 's01_e01_c01_u035', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c01_u001', 'reply_to': 's01_e01_c01_u034', 'timestamp': None, 'text': "No I don't, to hell with her, she left me!", 'meta': {'tokens': [['No', 'I', 'do', "n't", ',', 'to', 'hell', 'with', 'her', ',', 'she', 'left', 'me', '!']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[1, 2, 'Ross Geller'], [8, 9, 'Carol Willick'], [10, 11, 'Carol Willick'], [12, 13, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c01_u037', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c01_u001', 'reply_to': 's01_e01_c01_u036', 'timestamp': None, 'text': "No!! Okay?! Why does everyone keep fixating on that? She didn't know, how should I know?", 'meta': {'tokens': [['No', '!!'], ['Okay', '?!'], ['Why', 'does', 'everyone', 'keep', 'fixating', 'on', 'that', '?'], ['She', 'did', "n't", 'know', ',', 'how', 'should', 'I', 'know', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [], [], [[0, 1, 'Carol Willick'], [7, 8, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c01_u039', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c01_u001', 'reply_to': 's01_e01_c01_u038', 'timestamp': None, 'text': 'I told mom and dad last night, they seemed to take it pretty well.', 'meta': {'tokens': [['I', 'told', 'mom', 'and', 'dad', 'last', 'night', ',', 'they', 'seemed', 'to', 'take', 'it', 'pretty', 'well', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller'], [2, 3, 'Judy Geller'], [4, 5, 'Jack Geller'], [8, 9, 'Jack Geller', 'Judy Geller']]]}}),
#  Utterance({'id': 's01_e01_c01_u041', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c01_u001', 'reply_to': 's01_e01_c01_u040', 'timestamp': None, 'text': 'Sorry.', 'meta': {'tokens': [['Sorry', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e01_c01_u045', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c01_u001', 'reply_to': 's01_e01_c01_u044', 'timestamp': None, 'text': "I don't want to be single, okay? I just... I just- I just wanna be married again!", 'meta': {'tokens': [['I', 'do', "n't", 'want', 'to', 'be', 'single', ',', 'okay', '?'], ['I', 'just', '...'], ['I', 'just', '-', 'I', 'just', 'wan', 'na', 'be', 'married', 'again', '!']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller']], [[0, 1, 'Ross Geller']], [[0, 1, 'Ross Geller'], [3, 4, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c01_u053', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c01_u001', 'reply_to': 's01_e01_c01_u052', 'timestamp': None, 'text': 'Hi.', 'meta': {'tokens': [['Hi', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e01_c02_u003', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c02_u001', 'reply_to': 's01_e01_c02_u002', 'timestamp': None, 'text': "I'll have whatever Christine is having.", 'meta': {'tokens': [['I', "'ll", 'have', 'whatever', 'Christine', 'is', 'having', '.']], 'transcript_with_note': "(in a deep voice) I'll have whatever Christine is having.", 'tokens_with_note': [['(', 'in', 'a', 'deep', 'voice', ')', 'I', "'ll", 'have', 'whatever', 'Christine', 'is', 'having', '.']], 'character_entities': [[[0, 1, 'Ross Geller'], [4, 5, 'Christine']]]}}),
#  Utterance({'id': 's01_e01_c02_u012', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c02_u001', 'reply_to': 's01_e01_c02_u011', 'timestamp': None, 'text': "You can see where he'd have trouble.", 'meta': {'tokens': [['You', 'can', 'see', 'where', 'he', "'d", 'have', 'trouble', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, '#GENERAL#', 'Rachel Green'], [4, 5, 'Leonard Green']]]}}),
#  Utterance({'id': 's01_e01_c02_u030', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c02_u001', 'reply_to': 's01_e01_c02_u029', 'timestamp': None, 'text': 'Paul the Wine Guy, Paul?', 'meta': {'tokens': [['Paul', 'the', 'Wine', 'Guy', ',', 'Paul', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Paul the Wine Guy'], [5, 6, 'Paul the Wine Guy']]]}}),
#  Utterance({'id': 's01_e01_c02_u032', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c02_u001', 'reply_to': 's01_e01_c02_u031', 'timestamp': None, 'text': 'He finally asked you out?', 'meta': {'tokens': [['He', 'finally', 'asked', 'you', 'out', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Paul the Wine Guy'], [3, 4, 'Monica Geller']]]}}),
#  Utterance({'id': 's01_e01_c02_u038', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c02_u001', 'reply_to': 's01_e01_c02_u037', 'timestamp': None, 'text': "That'd be good...", 'meta': {'tokens': [['That', "'d", 'be', 'good', '...']], 'transcript_with_note': "(choked voice) That'd be good...", 'tokens_with_note': [['(', 'choked', 'voice', ')', 'That', "'d", 'be', 'good', '...']], 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e01_c02_u040', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c02_u001', 'reply_to': 's01_e01_c02_u039', 'timestamp': None, 'text': "No, go on! It's Paul the Wine Guy!", 'meta': {'tokens': [['No', ',', 'go', 'on', '!'], ['It', "'s", 'Paul', 'the', 'Wine', 'Guy', '!']], 'transcript_with_note': "(normal voice) No, go on! It's Paul the Wine Guy!", 'tokens_with_note': [['(', 'normal', 'voice', ')', 'No', ',', 'go', 'on', '!'], ['It', "'s", 'Paul', 'the', 'Wine', 'Guy', '!']], 'character_entities': [[], [[2, 3, 'Paul the Wine Guy']]]}}),
#  Utterance({'id': 's01_e01_c02_u047', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c02_u001', 'reply_to': 's01_e01_c02_u046', 'timestamp': None, 'text': 'A wandering?', 'meta': {'tokens': [['A', 'wandering', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e01_c02_u055', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c02_u001', 'reply_to': 's01_e01_c02_u054', 'timestamp': None, 'text': "So Rachel, what're you, uh... what're you up to tonight?", 'meta': {'tokens': [['So', 'Rachel', ',', 'what', "'re", 'you', ',', 'uh', '...'], ['what', "'re", 'you', 'up', 'to', 'tonight', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[5, 6, 'Rachel Green']], [[2, 3, 'Rachel Green']]]}}),
#  Utterance({'id': 's01_e01_c02_u057', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c02_u001', 'reply_to': 's01_e01_c02_u056', 'timestamp': None, 'text': "Right, you're not even getting your honeymoon, God.. No, no, although, Aruba, this time of year... talk about your- -big lizards... Anyway, if you don't feel like being alone tonight, Joey and Chandler are coming over to help me put together my new furniture.", 'meta': {'tokens': [['Right', ',', 'you', "'re", 'not', 'even', 'getting', 'your', 'honeymoon', ',', 'God', '..'], ['No', ',', 'no', ',', 'although', ',', 'Aruba', ',', 'this', 'time', 'of', 'year', '...'], ['talk', 'about', 'your', '-', '-', 'big', 'lizards', '...'], ['Anyway', ',', 'if', 'you', 'do', "n't", 'feel', 'like', 'being', 'alone', 'tonight', ',', 'Joey', 'and', 'Chandler', 'are', 'coming', 'over', 'to', 'help', 'me', 'put', 'together', 'my', 'new', 'furniture', '.']], 'transcript_with_note': "Right, you're not even getting your honeymoon, God.. No, no, although, Aruba, this time of year... talk about your- (thinks) -big lizards... Anyway, if you don't feel like being alone tonight, Joey and Chandler are coming over to help me put together my new furniture.", 'tokens_with_note': [['Right', ',', 'you', "'re", 'not', 'even', 'getting', 'your', 'honeymoon', ',', 'God', '..'], ['No', ',', 'no', ',', 'although', ',', 'Aruba', ',', 'this', 'time', 'of', 'year', '...'], ['talk', 'about', 'your', '-', '(', 'thinks', ')', '-', 'big', 'lizards', '...'], ['Anyway', ',', 'if', 'you', 'do', "n't", 'feel', 'like', 'being', 'alone', 'tonight', ',', 'Joey', 'and', 'Chandler', 'are', 'coming', 'over', 'to', 'help', 'me', 'put', 'together', 'my', 'new', 'furniture', '.']], 'character_entities': [[[2, 3, 'Rachel Green'], [7, 8, 'Rachel Green']], [], [[2, 3, '#GENERAL#', 'Rachel Green']], [[3, 4, 'Rachel Green'], [12, 13, 'Joey Tribbiani'], [14, 15, 'Chandler Bing'], [20, 21, 'Ross Geller'], [23, 24, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c02_u060', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c02_u001', 'reply_to': 's01_e01_c02_u059', 'timestamp': None, 'text': 'Okay, sure.', 'meta': {'tokens': [['Okay', ',', 'sure', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e01_c04_u001', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c04_u001', 'reply_to': None, 'timestamp': None, 'text': "I'm supposed to attach a brackety thing to the side things, using a bunch of these little worm guys. I have no brackety thing, I see no whim guys whatsoever and- I cannot feel my legs.", 'meta': {'tokens': [['I', "'m", 'supposed', 'to', 'attach', 'a', 'brackety', 'thing', 'to', 'the', 'side', 'things', ',', 'using', 'a', 'bunch', 'of', 'these', 'little', 'worm', 'guys', '.'], ['I', 'have', 'no', 'brackety', 'thing', ',', 'I', 'see', 'no', 'whim', 'guys', 'whatsoever', 'and', '-', 'I', 'can', 'not', 'feel', 'my', 'legs', '.']], 'transcript_with_note': "(squatting and reading the instructions) I'm supposed to attach a brackety thing to the side things, using a bunch of these little worm guys. I have no brackety thing, I see no whim guys whatsoever and- I cannot feel my legs.", 'tokens_with_note': [['(', 'squatting', 'and', 'reading', 'the', 'instructions', ')', 'I', "'m", 'supposed', 'to', 'attach', 'a', 'brackety', 'thing', 'to', 'the', 'side', 'things', ',', 'using', 'a', 'bunch', 'of', 'these', 'little', 'worm', 'guys', '.'], ['I', 'have', 'no', 'brackety', 'thing', ',', 'I', 'see', 'no', 'whim', 'guys', 'whatsoever', 'and', '-', 'I', 'can', 'not', 'feel', 'my', 'legs', '.']], 'character_entities': [[[0, 1, 'Ross Geller']], [[0, 1, 'Ross Geller'], [6, 7, 'Ross Geller'], [14, 15, 'Ross Geller'], [18, 19, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c04_u012', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c04_u001', 'reply_to': 's01_e01_c04_u011', 'timestamp': None, 'text': "This was Carol's favorite beer. She always drank it out of the can, I should have known.", 'meta': {'tokens': [['This', 'was', 'Carol', "'s", 'favorite', 'beer', '.'], ['She', 'always', 'drank', 'it', 'out', 'of', 'the', 'can', ',', 'I', 'should', 'have', 'known', '.']], 'transcript_with_note': "(clutching a beer can and sniffing) This was Carol's favorite beer. She always drank it out of the can, I should have known.", 'tokens_with_note': [['(', 'clutching', 'a', 'beer', 'can', 'and', 'sniffing', ')', 'This', 'was', 'Carol', "'s", 'favorite', 'beer', '.'], ['She', 'always', 'drank', 'it', 'out', 'of', 'the', 'can', ',', 'I', 'should', 'have', 'known', '.']], 'character_entities': [[[2, 3, 'Carol Willick']], [[0, 1, 'Carol Willick'], [9, 10, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c04_u016', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c04_u001', 'reply_to': 's01_e01_c04_u015', 'timestamp': None, 'text': 'You guys.', 'meta': {'tokens': [['You', 'guys', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Joey Tribbiani', 'Chandler Bing']]]}}),
#  Utterance({'id': 's01_e01_c07_u001', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c07_u001', 'reply_to': None, 'timestamp': None, 'text': "I'm divorced! I'm only 26 and I'm divorced!", 'meta': {'tokens': [['I', "'m", 'divorced', '!'], ['I', "'m", 'only', '26', 'and', 'I', "'m", 'divorced', '!']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller']], [[0, 1, 'Ross Geller'], [5, 6, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c07_u004', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c07_u001', 'reply_to': 's01_e01_c07_u003', 'timestamp': None, 'text': 'That only took me an hour.', 'meta': {'tokens': [['That', 'only', 'took', 'me', 'an', 'hour', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[3, 4, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c07_u006', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c07_u001', 'reply_to': 's01_e01_c07_u005', 'timestamp': None, 'text': "You know what the scariest part is? What if there's only one woman for everybody, y'know? I mean what if you get one woman- and that's it? Unfortunately in my case, there was only one woman- for her...", 'meta': {'tokens': [['You', 'know', 'what', 'the', 'scariest', 'part', 'is', '?'], ['What', 'if', 'there', "'s", 'only', 'one', 'woman', 'for', 'everybody', ',', "y'know", '?'], ['I', 'mean', 'what', 'if', 'you', 'get', 'one', 'woman', '-', 'and', 'that', "'s", 'it', '?'], ['Unfortunately', 'in', 'my', 'case', ',', 'there', 'was', 'only', 'one', 'woman', '-', 'for', 'her', '...']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Chandler Bing']], [[6, 7, '#GENERAL#']], [[0, 1, 'Ross Geller'], [4, 5, '#GENERAL#', 'Chandler Bing'], [7, 8, '#GENERAL#']], [[2, 3, 'Ross Geller'], [9, 10, '#GENERAL#'], [12, 13, '#GENERAL#']]]}}),
#  Utterance({'id': 's01_e01_c07_u008', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c07_u001', 'reply_to': 's01_e01_c07_u007', 'timestamp': None, 'text': "I honestly don't know if I'm hungry or horny.", 'meta': {'tokens': [['I', 'honestly', 'do', "n't", 'know', 'if', 'I', "'m", 'hungry', 'or', 'horny', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller'], [6, 7, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c10_u001', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c10_u001', 'reply_to': None, 'timestamp': None, 'text': "Grab a spoon. Do you know how long it's been since I've grabbed a spoon? Do the words 'Billy, don't be a hero' mean anything to you?", 'meta': {'tokens': [['Grab', 'a', 'spoon', '.'], ['Do', 'you', 'know', 'how', 'long', 'it', "'s", 'been', 'since', 'I', "'ve", 'grabbed', 'a', 'spoon', '?'], ['Do', 'the', 'words', "'", 'Billy', ',', 'do', "n't", 'be', 'a', 'hero', "'", 'mean', 'anything', 'to', 'you', '?']], 'transcript_with_note': "(scornful) Grab a spoon. Do you know how long it's been since I've grabbed a spoon? Do the words 'Billy, don't be a hero' mean anything to you?", 'tokens_with_note': [['(', 'scornful', ')', 'Grab', 'a', 'spoon', '.'], ['Do', 'you', 'know', 'how', 'long', 'it', "'s", 'been', 'since', 'I', "'ve", 'grabbed', 'a', 'spoon', '?'], ['Do', 'the', 'words', "'", 'Billy', ',', 'do', "n't", 'be', 'a', 'hero', "'", 'mean', 'anything', 'to', 'you', '?']], 'character_entities': [[], [[1, 2, 'Joey Tribbiani'], [9, 10, 'Ross Geller']], [[4, 5, '#GENERAL#'], [10, 11, '#GENERAL#'], [15, 16, 'Joey Tribbiani']]]}}),
#  Utterance({'id': 's01_e01_c10_u005', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c10_u001', 'reply_to': 's01_e01_c10_u004', 'timestamp': None, 'text': "Y'know, here's the thing. Even if I could get it together enough to- to ask a woman out,... who am I gonna ask?", 'meta': {'tokens': [["Y'know", ',', 'here', "'s", 'the', 'thing', '.'], ['Even', 'if', 'I', 'could', 'get', 'it', 'together', 'enough', 'to', '-', 'to', 'ask', 'a', 'woman', 'out', ',', '...'], ['who', 'am', 'I', 'gon', 'na', 'ask', '?']], 'transcript_with_note': "Y'know, here's the thing. Even if I could get it together enough to- to ask a woman out,... who am I gonna ask? (He gazes out of the window.)", 'tokens_with_note': [["Y'know", ',', 'here', "'s", 'the', 'thing', '.'], ['Even', 'if', 'I', 'could', 'get', 'it', 'together', 'enough', 'to', '-', 'to', 'ask', 'a', 'woman', 'out', ',', '...'], ['who', 'am', 'I', 'gon', 'na', 'ask', '?'], ['(', 'He', 'gazes', 'out', 'of', 'the', 'window', '.', ')']], 'character_entities': [[], [[2, 3, 'Ross Geller'], [13, 14, '#GENERAL#']], [[2, 3, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c13_u003', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c13_u001', 'reply_to': 's01_e01_c13_u002', 'timestamp': None, 'text': "I assume we're looking for an answer more sophisticated than 'to get you into bed'.", 'meta': {'tokens': [['I', 'assume', 'we', "'re", 'looking', 'for', 'an', 'answer', 'more', 'sophisticated', 'than', "'", 'to', 'get', 'you', 'into', 'bed', "'", '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller'], [2, 3, 'Ross Geller', 'Joey Tribbiani', 'Phoebe Buffay', 'Monica Geller'], [14, 15, 'Monica Geller']]]}}),
#  Utterance({'id': 's01_e01_c13_u012', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c13_u001', 'reply_to': 's01_e01_c13_u011', 'timestamp': None, 'text': 'You got a job?', 'meta': {'tokens': [['You', 'got', 'a', 'job', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Rachel Green']]]}}),
#  Utterance({'id': 's01_e01_c14_u008', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u007', 'timestamp': None, 'text': "The word you're looking for is 'Anyway'...", 'meta': {'tokens': [['The', 'word', 'you', "'re", 'looking', 'for', 'is', "'", 'Anyway', "'", '...']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[2, 3, 'Phoebe Buffay']]]}}),
#  Utterance({'id': 's01_e01_c14_u013', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u012', 'timestamp': None, 'text': 'Come on, you made coffee! You can do anything!', 'meta': {'tokens': [['Come', 'on', ',', 'you', 'made', 'coffee', '!'], ['You', 'can', 'do', 'anything', '!']], 'transcript_with_note': 'Come on, you made coffee! You can do anything! (Chandler slowly tries to hide the now dead plant from that morning when he and Joey poured their coffee into it.)', 'tokens_with_note': [['Come', 'on', ',', 'you', 'made', 'coffee', '!'], ['You', 'can', 'do', 'anything', '!'], ['(', 'Chandler', 'slowly', 'tries', 'to', 'hide', 'the', 'now', 'dead', 'plant', 'from', 'that', 'morning', 'when', 'he', 'and', 'Joey', 'poured', 'their', 'coffee', 'into', 'it', '.', ')']], 'character_entities': [[[3, 4, 'Rachel Green']], [[0, 1, 'Rachel Green']]]}}),
#  Utterance({'id': 's01_e01_c14_u014', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u013', 'timestamp': None, 'text': "C'mon, cut. Cut, cut, cut,...", 'meta': {'tokens': [["C'mon", ',', 'cut', '.'], ['Cut', ',', 'cut', ',', 'cut', ',', '...']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], []]}}),
#  Utterance({'id': 's01_e01_c14_u024', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u023', 'timestamp': None, 'text': 'No. No, I gotta go home sometime.', 'meta': {'tokens': [['No', '.'], ['No', ',', 'I', 'got', 'ta', 'go', 'home', 'sometime', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [[2, 3, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c14_u026', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u025', 'timestamp': None, 'text': 'Yeah.', 'meta': {'tokens': [['Yeah', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e01_c14_u031', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u030', 'timestamp': None, 'text': 'Mmm. Oh, no-', 'meta': {'tokens': [['Mmm.', 'Oh', ',', 'no', '-']], 'transcript_with_note': 'Mmm. (They both reach for the last cookie) Oh, no-', 'tokens_with_note': [['Mmm.', '(', 'They', 'both', 'reach', 'for', 'the', 'last', 'cookie', ')', 'Oh', ',', 'no', '-']], 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e01_c14_u033', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u032', 'timestamp': None, 'text': 'No no no, go-', 'meta': {'tokens': [['No', 'no', 'no', ',', 'go', '-']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e01_c14_u035', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u034', 'timestamp': None, 'text': 'Split it?', 'meta': {'tokens': [['Split', 'it', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e01_c14_u037', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u036', 'timestamp': None, 'text': "Okay. You know you probably didn't know this, but back in high school, I had a, um, major crush on you.", 'meta': {'tokens': [['Okay', '.'], ['You', 'know', 'you', 'probably', 'did', "n't", 'know', 'this', ',', 'but', 'back', 'in', 'high', 'school', ',', 'I', 'had', 'a', ',', 'um', ',', 'major', 'crush', 'on', 'you', '.']], 'transcript_with_note': "Okay. (They split it.) You know you probably didn't know this, but back in high school, I had a, um, major crush on you.", 'tokens_with_note': [['Okay', '.'], ['(', 'They', 'split', 'it', '.', ')'], ['You', 'know', 'you', 'probably', 'did', "n't", 'know', 'this', ',', 'but', 'back', 'in', 'high', 'school', ',', 'I', 'had', 'a', ',', 'um', ',', 'major', 'crush', 'on', 'you', '.']], 'character_entities': [[], [[0, 1, 'Rachel Green'], [2, 3, 'Rachel Green'], [15, 16, 'Ross Geller'], [24, 25, 'Rachel Green']]]}}),
#  Utterance({'id': 's01_e01_c14_u039', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u038', 'timestamp': None, 'text': "You did! Oh.... I always figured you just thought I was Monica's geeky older brother.", 'meta': {'tokens': [['You', 'did', '!'], ['Oh', '....'], ['I', 'always', 'figured', 'you', 'just', 'thought', 'I', 'was', 'Monica', "'s", 'geeky', 'older', 'brother', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Rachel Green']], [], [[0, 1, 'Ross Geller'], [3, 4, 'Rachel Green'], [6, 7, 'Ross Geller'], [8, 9, 'Monica Geller'], [12, 13, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c14_u041', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u040', 'timestamp': None, 'text': 'Oh. Listen, do you think- and try not to let my intense vulnerability become any kind of a factor here- but do you think it would be okay if I asked you out? Sometime? Maybe?', 'meta': {'tokens': [['Oh', '.'], ['Listen', ',', 'do', 'you', 'think', '-', 'and', 'try', 'not', 'to', 'let', 'my', 'intense', 'vulnerability', 'become', 'any', 'kind', 'of', 'a', 'factor', 'here', '-', 'but', 'do', 'you', 'think', 'it', 'would', 'be', 'okay', 'if', 'I', 'asked', 'you', 'out', '?'], ['Sometime', '?'], ['Maybe', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [[3, 4, 'Rachel Green'], [11, 12, 'Ross Geller'], [24, 25, 'Rachel Green'], [31, 32, 'Ross Geller'], [33, 34, 'Rachel Green']], [], []]}}),
#  Utterance({'id': 's01_e01_c14_u043', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u042', 'timestamp': None, 'text': 'Okay... okay, maybe I will...', 'meta': {'tokens': [['Okay', '...'], ['okay', ',', 'maybe', 'I', 'will', '...']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [[3, 4, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c14_u045', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u044', 'timestamp': None, 'text': 'Goodnight.', 'meta': {'tokens': [['Goodnight', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e01_c14_u048', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c14_u001', 'reply_to': 's01_e01_c14_u047', 'timestamp': None, 'text': 'I just grabbed a spoon.', 'meta': {'tokens': [['I', 'just', 'grabbed', 'a', 'spoon', '.']], 'transcript_with_note': 'I just grabbed a spoon. (Ross exits and Monica has no idea what that means.)', 'tokens_with_note': [['I', 'just', 'grabbed', 'a', 'spoon', '.'], ['(', 'Ross', 'exits', 'and', 'Monica', 'has', 'no', 'idea', 'what', 'that', 'means', '.', ')']], 'character_entities': [[[0, 1, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e01_c15_u010', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e01_c15_u001', 'reply_to': 's01_e01_c15_u009', 'timestamp': None, 'text': "There's an image.", 'meta': {'tokens': [['There', "'s", 'an', 'image', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e02_c01_u007', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c01_u001', 'reply_to': 's01_e02_c01_u006', 'timestamp': None, 'text': "Yeah, and-and it's not that we don't like the comedian, it's that-that... that's not why we bought the ticket.", 'meta': {'tokens': [['Yeah', ',', 'and', '-', 'and', 'it', "'s", 'not', 'that', 'we', 'do', "n't", 'like', 'the', 'comedian', ',', 'it', "'s", 'that', '-', 'that', '...'], ['that', "'s", 'not', 'why', 'we', 'bought', 'the', 'ticket', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[9, 10, 'Ross Geller', 'Joey Tribbiani', '#GENERAL#', 'Phoebe Buffay', 'Rachel Green', 'Monica Geller', 'Chandler Bing'], [14, 15, '#GENERAL#']], [[4, 5, 'Ross Geller', 'Joey Tribbiani', '#GENERAL#', 'Phoebe Buffay', 'Rachel Green', 'Monica Geller', 'Chandler Bing']]]}}),
#  Utterance({'id': 's01_e02_c02_u001', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c02_u001', 'reply_to': None, 'timestamp': None, 'text': "No, it's good, it is good, it's just that- mm- doesn't she seem a little angry?", 'meta': {'tokens': [['No', ',', 'it', "'s", 'good', ',', 'it', 'is', 'good', ',', 'it', "'s", 'just', 'that', '-', 'mm', '-', 'does', "n't", 'she', 'seem', 'a', 'little', 'angry', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[19, 20, 'Woman 1']]]}}),
#  Utterance({'id': 's01_e02_c02_u003', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c02_u001', 'reply_to': 's01_e02_c02_u002', 'timestamp': None, 'text': 'Does she.', 'meta': {'tokens': [['Does', 'she', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[1, 2, 'Woman 1']]]}}),
#  Utterance({'id': 's01_e02_c02_u005', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c02_u001', 'reply_to': 's01_e02_c02_u004', 'timestamp': None, 'text': "Marsha, these are cave people. Okay? They have issues like 'Gee, that glacier's getting kinda close.' See?", 'meta': {'tokens': [['Marsha', ',', 'these', 'are', 'cave', 'people', '.'], ['Okay', '?'], ['They', 'have', 'issues', 'like', "'", 'Gee', ',', 'that', 'glacier', "'s", 'getting', 'kinda', 'close', '.'], ["'", 'See', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [], [[0, 1, '#GENERAL#']], []]}}),
#  Utterance({'id': 's01_e02_c02_u008', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c02_u001', 'reply_to': 's01_e02_c02_u007', 'timestamp': None, 'text': 'No. No.', 'meta': {'tokens': [['No', '.'], ['No', '.']], 'transcript_with_note': '(trying to ignore her) No. No.', 'tokens_with_note': [['(', 'trying', 'to', 'ignore', 'her', ')', 'No', '.'], ['No', '.']], 'character_entities': [[], []]}}),
#  Utterance({'id': 's01_e02_c02_u010', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c02_u001', 'reply_to': 's01_e02_c02_u009', 'timestamp': None, 'text': "Okay, okay, yes, it is. How about I'll, uh, catch up with you in the Ice Age.", 'meta': {'tokens': [['Okay', ',', 'okay', ',', 'yes', ',', 'it', 'is', '.'], ['How', 'about', 'I', "'ll", ',', 'uh', ',', 'catch', 'up', 'with', 'you', 'in', 'the', 'Ice', 'Age', '.']], 'transcript_with_note': "Okay, okay, yes, it is. (waves) How about I'll, uh, catch up with you in the Ice Age.", 'tokens_with_note': [['Okay', ',', 'okay', ',', 'yes', ',', 'it', 'is', '.'], ['(', 'waves', ')', 'How', 'about', 'I', "'ll", ',', 'uh', ',', 'catch', 'up', 'with', 'you', 'in', 'the', 'Ice', 'Age', '.']], 'character_entities': [[], [[2, 3, 'Ross Geller'], [10, 11, 'Marsha']]]}}),
#  Utterance({'id': 's01_e02_c02_u012', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c02_u001', 'reply_to': 's01_e02_c02_u011', 'timestamp': None, 'text': 'Hi.', 'meta': {'tokens': [['Hi', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e02_c02_u014', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c02_u001', 'reply_to': 's01_e02_c02_u013', 'timestamp': None, 'text': 'You look great. I, uh... I hate that.', 'meta': {'tokens': [['You', 'look', 'great', '.'], ['I', ',', 'uh', '...'], ['I', 'hate', 'that', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Carol Willick']], [[0, 1, 'Ross Geller']], [[0, 1, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e02_c02_u016', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c02_u001', 'reply_to': 's01_e02_c02_u015', 'timestamp': None, 'text': "Ah, well, in here, anyone who... stands erect... So what's new? Still, uh...", 'meta': {'tokens': [['Ah', ',', 'well', ',', 'in', 'here', ',', 'anyone', 'who', '...'], ['stands', 'erect', '...'], ['So', 'what', "'s", 'new', '?'], ['Still', ',', 'uh', '...']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [], [], []]}}),
#  Utterance({'id': 's01_e02_c02_u018', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c02_u001', 'reply_to': 's01_e02_c02_u017', 'timestamp': None, 'text': "Well... you never know. How's, um.. how's the family?", 'meta': {'tokens': [['Well', '...'], ['you', 'never', 'know', '.'], ['How', "'s", ',', 'um', '..'], ['how', "'s", 'the', 'family', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [[0, 1, 'Carol Willick']], [], [[3, 4, '#GENERAL#']]]}}),
#  Utterance({'id': 's01_e02_c02_u020', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c02_u001', 'reply_to': 's01_e02_c02_u019', 'timestamp': None, 'text': 'Why- why are you here, Carol?', 'meta': {'tokens': [['Why', '-', 'why', 'are', 'you', 'here', ',', 'Carol', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[4, 5, 'Carol Willick'], [7, 8, 'Carol Willick']]]}}),
#  Utterance({'id': 's01_e02_c02_u022', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c02_u001', 'reply_to': 's01_e02_c02_u021', 'timestamp': None, 'text': 'Pregnant?!', 'meta': {'tokens': [['Pregnant', '?!']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e02_c03_u040', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c03_u001', 'reply_to': 's01_e02_c03_u039', 'timestamp': None, 'text': '.....Hi.', 'meta': {'tokens': [['.....'], ['Hi', '.']], 'transcript_with_note': '(standing outside the door).....Hi.', 'tokens_with_note': [['(', 'standing', 'outside', 'the', 'door', ')', '.....'], ['Hi', '.']], 'character_entities': [[], []]}}),
#  Utterance({'id': 's01_e02_c03_u042', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c03_u001', 'reply_to': 's01_e02_c03_u041', 'timestamp': None, 'text': "Carol's pregnant.", 'meta': {'tokens': [['Carol', "'s", 'pregnant', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Carol Willick']]]}}),
#  Utterance({'id': 's01_e02_c03_u045', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c03_u001', 'reply_to': 's01_e02_c03_u044', 'timestamp': None, 'text': 'Yeah. Do that for another two hours, you might be where I am right about now.', 'meta': {'tokens': [['Yeah', '.'], ['Do', 'that', 'for', 'another', 'two', 'hours', ',', 'you', 'might', 'be', 'where', 'I', 'am', 'right', 'about', 'now', '.']], 'transcript_with_note': 'Yeah. Do that for another two hours, you might be where I am right about now. (He enters.)', 'tokens_with_note': [['Yeah', '.'], ['Do', 'that', 'for', 'another', 'two', 'hours', ',', 'you', 'might', 'be', 'where', 'I', 'am', 'right', 'about', 'now', '.'], ['(', 'He', 'enters', '.', ')']], 'character_entities': [[], [[7, 8, 'Monica Geller'], [11, 12, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e02_c03_u048', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c03_u001', 'reply_to': 's01_e02_c03_u047', 'timestamp': None, 'text': "Well, Carol says she and Susan want me to be involved, but if I'm not comfortable with it, I don't have to be involved.. basically it's entirely up to me.", 'meta': {'tokens': [['Well', ',', 'Carol', 'says', 'she', 'and', 'Susan', 'want', 'me', 'to', 'be', 'involved', ',', 'but', 'if', 'I', "'m", 'not', 'comfortable', 'with', 'it', ',', 'I', 'do', "n't", 'have', 'to', 'be', 'involved', '..'], ['basically', 'it', "'s", 'entirely', 'up', 'to', 'me', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[2, 3, 'Carol Willick'], [4, 5, 'Carol Willick'], [6, 7, 'Susan Bunch'], [8, 9, 'Ross Geller'], [15, 16, 'Ross Geller'], [22, 23, 'Ross Geller']], [[6, 7, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e02_c03_u052', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c03_u001', 'reply_to': 's01_e02_c03_u051', 'timestamp': None, 'text': 'Anyway, they want me to go down to this- sonogram thing with them tomorrow.', 'meta': {'tokens': [['Anyway', ',', 'they', 'want', 'me', 'to', 'go', 'down', 'to', 'this', '-', 'sonogram', 'thing', 'with', 'them', 'tomorrow', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[2, 3, 'Susan Bunch', 'Carol Willick'], [4, 5, 'Ross Geller'], [14, 15, 'Susan Bunch', 'Carol Willick']]]}}),
#  Utterance({'id': 's01_e02_c03_u054', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c03_u001', 'reply_to': 's01_e02_c03_u053', 'timestamp': None, 'text': "I have no idea. No matter what I do, though, I'm still gonna be a father.", 'meta': {'tokens': [['I', 'have', 'no', 'idea', '.'], ['No', 'matter', 'what', 'I', 'do', ',', 'though', ',', 'I', "'m", 'still', 'gon', 'na', 'be', 'a', 'father', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller']], [[3, 4, 'Ross Geller'], [8, 9, 'Ross Geller'], [15, 16, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e02_c04_u004', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c04_u001', 'reply_to': 's01_e02_c04_u003', 'timestamp': None, 'text': "I- I think they're great! I, I really do.", 'meta': {'tokens': [['I', '-', 'I', 'think', 'they', "'re", 'great', '!'], ['I', ',', 'I', 'really', 'do', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller'], [2, 3, 'Ross Geller'], [4, 5, 'Non-Entity']], [[0, 1, 'Ross Geller'], [2, 3, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e02_c04_u005', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c04_u001', 'reply_to': 's01_e02_c04_u004', 'timestamp': None, 'text': "Do you remember the Ludwins? The big one had a thing for you, didn't she?", 'meta': {'tokens': [['Do', 'you', 'remember', 'the', 'Ludwins', '?'], ['The', 'big', 'one', 'had', 'a', 'thing', 'for', 'you', ',', 'did', "n't", 'she', '?']], 'transcript_with_note': "(To Ross) Do you remember the Ludwins? The big one had a thing for you, didn't she?", 'tokens_with_note': [['(', 'To', 'Ross', ')', 'Do', 'you', 'remember', 'the', 'Ludwins', '?'], ['The', 'big', 'one', 'had', 'a', 'thing', 'for', 'you', ',', 'did', "n't", 'she', '?']], 'character_entities': [[[1, 2, 'Ross Geller'], [4, 5, 'Ludwins']], [[2, 3, "Martha Ludwin's daughter 2"], [7, 8, 'Ross Geller'], [11, 12, "Martha Ludwin's daughter 2"]]]}}),
#  Utterance({'id': 's01_e02_c04_u007', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c04_u001', 'reply_to': 's01_e02_c04_u006', 'timestamp': None, 'text': 'Aw, Mom...', 'meta': {'tokens': [['Aw', ',', 'Mom', '...']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[2, 3, 'Judy Geller']]]}}),
#  Utterance({'id': 's01_e02_c04_u013', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c04_u001', 'reply_to': 's01_e02_c04_u012', 'timestamp': None, 'text': 'Yeah.', 'meta': {'tokens': [['Yeah', '.']], 'transcript_with_note': 'Yeah. (They go to the kitchen.)', 'tokens_with_note': [['Yeah', '.'], ['(', 'They', 'go', 'to', 'the', 'kitchen', '.', ')']], 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e02_c04_u018', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c04_u001', 'reply_to': 's01_e02_c04_u017', 'timestamp': None, 'text': "I'm not gonna tell you what they spent on that wedding... but forty thousand dollars is a lot of money!", 'meta': {'tokens': [['I', "'m", 'not', 'gon', 'na', 'tell', 'you', 'what', 'they', 'spent', 'on', 'that', 'wedding', '...'], ['but', 'forty', 'thousand', 'dollars', 'is', 'a', 'lot', 'of', 'money', '!']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Jack Geller'], [6, 7, 'Ross Geller', 'Judy Geller', 'Monica Geller'], [8, 9, '#GENERAL#']], []]}}),
#  Utterance({'id': 's01_e02_c04_u023', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c04_u001', 'reply_to': 's01_e02_c04_u022', 'timestamp': None, 'text': "Don't listen to your mother. You're independent, and you always have been! Even when you were a kid... and you were chubby, and you had no friends, you were just fine! And you would read alone in your room, and your puzzles...", 'meta': {'tokens': [['Do', "n't", 'listen', 'to', 'your', 'mother', '.'], ['You', "'re", 'independent', ',', 'and', 'you', 'always', 'have', 'been', '!'], ['Even', 'when', 'you', 'were', 'a', 'kid', '...'], ['and', 'you', 'were', 'chubby', ',', 'and', 'you', 'had', 'no', 'friends', ',', 'you', 'were', 'just', 'fine', '!'], ['And', 'you', 'would', 'read', 'alone', 'in', 'your', 'room', ',', 'and', 'your', 'puzzles', '...']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[4, 5, 'Monica Geller']], [[0, 1, 'Monica Geller'], [5, 6, 'Monica Geller']], [[2, 3, 'Monica Geller'], [5, 6, '#OTHER#']], [[1, 2, 'Monica Geller'], [6, 7, 'Monica Geller'], [11, 12, 'Monica Geller']], [[1, 2, 'Monica Geller'], [6, 7, 'Monica Geller'], [10, 11, 'Monica Geller']]]}}),
#  Utterance({'id': 's01_e02_c04_u025', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c04_u001', 'reply_to': 's01_e02_c04_u024', 'timestamp': None, 'text': "Look, there are people like Ross who need to shoot for the stars, with his museum, and his papers getting published. Other people are satisfied with staying where they are- I'm telling you, these are the people who never get cancer.", 'meta': {'tokens': [['Look', ',', 'there', 'are', 'people', 'like', 'Ross', 'who', 'need', 'to', 'shoot', 'for', 'the', 'stars', ',', 'with', 'his', 'museum', ',', 'and', 'his', 'papers', 'getting', 'published', '.'], ['Other', 'people', 'are', 'satisfied', 'with', 'staying', 'where', 'they', 'are', '-', 'I', "'m", 'telling', 'you', ',', 'these', 'are', 'the', 'people', 'who', 'never', 'get', 'cancer', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[6, 7, 'Ross Geller'], [16, 17, 'Ross Geller'], [20, 21, 'Ross Geller']], [[7, 8, '#GENERAL#'], [10, 11, 'Jack Geller'], [13, 14, 'Monica Geller']]]}}),
#  Utterance({'id': 's01_e02_c04_u027', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c04_u001', 'reply_to': 's01_e02_c04_u026', 'timestamp': None, 'text': "...And I read about these women trying to have it all, and I thank God 'Our Little Harmonica' doesn't seem to have that problem.", 'meta': {'tokens': [['...'], ['And', 'I', 'read', 'about', 'these', 'women', 'trying', 'to', 'have', 'it', 'all', ',', 'and', 'I', 'thank', 'God', "'", 'Our', 'Little', 'Harmonica', "'", 'does', "n't", 'seem', 'to', 'have', 'that', 'problem', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [[1, 2, 'Jack Geller'], [9, 10, '#OTHER#'], [13, 14, 'Jack Geller'], [17, 18, 'Jack Geller', '#GENERAL#', 'Judy Geller']]]}}),
#  Utterance({'id': 's01_e02_c04_u029', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c04_u001', 'reply_to': 's01_e02_c04_u028', 'timestamp': None, 'text': "Okay! Okay. Look, I, uh- I realise you guys have been wondering what exactly happened between Carol and me, and, so, well, here's the deal. Carol's a lesbian. She's living with a woman named Susan. She's pregnant with my child, and she and Susan are going to raise the baby.", 'meta': {'tokens': [['Okay', '!'], ['Okay', '.'], ['Look', ',', 'I', ',', 'uh', '-', 'I', 'realise', 'you', 'guys', 'have', 'been', 'wondering', 'what', 'exactly', 'happened', 'between', 'Carol', 'and', 'me', ',', 'and', ',', 'so', ',', 'well', ',', 'here', "'s", 'the', 'deal', '.'], ['Carol', "'s", 'a', 'lesbian', '.'], ['She', "'s", 'living', 'with', 'a', 'woman', 'named', 'Susan', '.'], ['She', "'s", 'pregnant', 'with', 'my', 'child', ',', 'and', 'she', 'and', 'Susan', 'are', 'going', 'to', 'raise', 'the', 'baby', '.']], 'transcript_with_note': "(pulls his hand away) Okay! Okay. (To his parents) Look, I, uh- I realise you guys have been wondering what exactly happened between Carol and me, and, so, well, here's the deal. Carol's a lesbian. She's living with a woman named Susan. She's pregnant with my child, and she and Susan are going to raise the baby.", 'tokens_with_note': [['(', 'pulls', 'his', 'hand', 'away', ')', 'Okay', '!'], ['Okay', '.'], ['(', 'To', 'his', 'parents', ')', 'Look', ',', 'I', ',', 'uh', '-', 'I', 'realise', 'you', 'guys', 'have', 'been', 'wondering', 'what', 'exactly', 'happened', 'between', 'Carol', 'and', 'me', ',', 'and', ',', 'so', ',', 'well', ',', 'here', "'s", 'the', 'deal', '.'], ['Carol', "'s", 'a', 'lesbian', '.'], ['She', "'s", 'living', 'with', 'a', 'woman', 'named', 'Susan', '.'], ['She', "'s", 'pregnant', 'with', 'my', 'child', ',', 'and', 'she', 'and', 'Susan', 'are', 'going', 'to', 'raise', 'the', 'baby', '.']], 'character_entities': [[], [], [[2, 3, 'Ross Geller'], [6, 7, 'Ross Geller'], [8, 9, 'Jack Geller', 'Judy Geller', 'Monica Geller'], [17, 18, 'Carol Willick'], [19, 20, 'Ross Geller']], [[0, 1, 'Carol Willick']], [[0, 1, 'Carol Willick'], [5, 6, 'Susan Bunch'], [7, 8, '#OTHER#']], [[0, 1, 'Carol Willick'], [4, 5, 'Ross Geller'], [8, 9, 'Carol Willick'], [10, 11, 'Susan Bunch'], [16, 17, 'Ben Geller']]]}}),
#  Utterance({'id': 's01_e02_c05_u002', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c05_u001', 'reply_to': 's01_e02_c05_u001', 'timestamp': None, 'text': "Well, y'know, these people are pros. They know what they're doing, they take their time, they get the job done.", 'meta': {'tokens': [['Well', ',', "y'know", ',', 'these', 'people', 'are', 'pros', '.'], ['They', 'know', 'what', 'they', "'re", 'doing', ',', 'they', 'take', 'their', 'time', ',', 'they', 'get', 'the', 'job', 'done', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [[0, 1, '#GENERAL#', 'Jack Geller', 'Judy Geller'], [3, 4, '#GENERAL#', 'Jack Geller', 'Judy Geller'], [7, 8, '#GENERAL#', 'Jack Geller', 'Judy Geller'], [9, 10, '#GENERAL#', 'Jack Geller', 'Judy Geller'], [12, 13, '#GENERAL#', 'Jack Geller', 'Judy Geller']]]}}),
#  Utterance({'id': 's01_e02_c05_u004', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c05_u001', 'reply_to': 's01_e02_c05_u003', 'timestamp': None, 'text': 'Must pee.', 'meta': {'tokens': [['Must', 'pee', '.']], 'transcript_with_note': 'Must pee. (Goes to pee.)', 'tokens_with_note': [['Must', 'pee', '.'], ['(', 'Goes', 'to', 'pee', '.', ')']], 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e02_c05_u015', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c05_u001', 'reply_to': 's01_e02_c05_u014', 'timestamp': None, 'text': '...How long was I in there?', 'meta': {'tokens': [['...'], ['How', 'long', 'was', 'I', 'in', 'there', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [[3, 4, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e02_c05_u017', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e02_c05_u001', 'reply_to': 's01_e02_c05_u016', 'timestamp': None, 'text': "D'ya.. uh.. d'ya need any help?", 'meta': {'tokens': [["D'ya", '..'], ['uh', '..'], ["d'ya", 'need', 'any', 'help', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [], []]}}),
# ...
#  Utterance({'id': 's01_e24_c02_u029', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c02_u001', 'reply_to': 's01_e24_c02_u028', 'timestamp': None, 'text': ": Could you take it to Carol's every now and then, and show it to Ben, just so he doesn't forget me?", 'meta': {'tokens': [[':', 'Could', 'you', 'take', 'it', 'to', 'Carol', "'s", 'every', 'now', 'and', 'then', ',', 'and', 'show', 'it', 'to', 'Ben', ',', 'just', 'so', 'he', 'does', "n't", 'forget', 'me', '?']], 'transcript_with_note': "(to Monica): Could you take it to Carol's every now and then, and show it to Ben, just so he doesn't forget me?", 'tokens_with_note': [['(', 'to', 'Monica', ')', ':', 'Could', 'you', 'take', 'it', 'to', 'Carol', "'s", 'every', 'now', 'and', 'then', ',', 'and', 'show', 'it', 'to', 'Ben', ',', 'just', 'so', 'he', 'does', "n't", 'forget', 'me', '?']], 'character_entities': [[[2, 3, 'Monica Geller'], [4, 5, '#OTHER#'], [6, 7, 'Carol Willick'], [15, 16, '#OTHER#'], [17, 18, 'Ben Geller'], [21, 22, 'Ben Geller'], [25, 26, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e24_c02_u033', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c02_u001', 'reply_to': 's01_e24_c02_u032', 'timestamp': None, 'text': 'Hey, is Rachel here? Um, I wanted to wish her a happy birthday before I left.', 'meta': {'tokens': [['Hey', ',', 'is', 'Rachel', 'here', '?'], ['Um', ',', 'I', 'wanted', 'to', 'wish', 'her', 'a', 'happy', 'birthday', 'before', 'I', 'left', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[3, 4, 'Rachel Green']], [[2, 3, 'Ross Geller'], [6, 7, 'Rachel Green'], [11, 12, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e24_c02_u035', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c02_u001', 'reply_to': 's01_e24_c02_u034', 'timestamp': None, 'text': "Oh. Hey, who's Carl?", 'meta': {'tokens': [['Oh', '.'], ['Hey', ',', 'who', "'s", 'Carl', '?']], 'transcript_with_note': "Oh. (pause) Hey, who's Carl?", 'tokens_with_note': [['Oh', '.'], ['(', 'pause', ')', 'Hey', ',', 'who', "'s", 'Carl', '?']], 'character_entities': [[], [[4, 5, "Carl (Rachel's date)"]]]}}),
#  Utterance({'id': 's01_e24_c02_u037', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c02_u001', 'reply_to': 's01_e24_c02_u036', 'timestamp': None, 'text': 'No.', 'meta': {'tokens': [['No', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e24_c02_u039', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c02_u001', 'reply_to': 's01_e24_c02_u038', 'timestamp': None, 'text': 'At the coffeehouse, right.', 'meta': {'tokens': [['At', 'the', 'coffeehouse', ',', 'right', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e24_c02_u041', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c02_u001', 'reply_to': 's01_e24_c02_u040', 'timestamp': None, 'text': "OK, I'm gonna go say goodbye to the guys.", 'meta': {'tokens': [['OK', ',', 'I', "'m", 'gon', 'na', 'go', 'say', 'goodbye', 'to', 'the', 'guys', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[2, 3, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e24_c02_u044', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c02_u001', 'reply_to': 's01_e24_c02_u043', 'timestamp': None, 'text': 'Hi.', 'meta': {'tokens': [['Hi', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e24_c02_u047', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c02_u001', 'reply_to': 's01_e24_c02_u046', 'timestamp': None, 'text': '....I have to go to China.', 'meta': {'tokens': [['....'], ['I', 'have', 'to', 'go', 'to', 'China', '.']], 'transcript_with_note': '(sigh)....I have to go to China.', 'tokens_with_note': [['(', 'sigh', ')', '....'], ['I', 'have', 'to', 'go', 'to', 'China', '.']], 'character_entities': [[], [[0, 1, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e24_c02_u049', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c02_u001', 'reply_to': 's01_e24_c02_u048', 'timestamp': None, 'text': "No no, this big pile of dishes in my mom's breakfront. Do you guys know who Carl is?", 'meta': {'tokens': [['No', 'no', ',', 'this', 'big', 'pile', 'of', 'dishes', 'in', 'my', 'mom', "'s", 'breakfront', '.'], ['Do', 'you', 'guys', 'know', 'who', 'Carl', 'is', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[9, 10, 'Ross Geller']], [[1, 2, 'Ross Geller', 'Joey Tribbiani', '#GENERAL#'], [5, 6, "Carl (Rachel's date)"]]]}}),
#  Utterance({'id': 's01_e24_c02_u051', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c02_u001', 'reply_to': 's01_e24_c02_u050', 'timestamp': None, 'text': "Well, Rachel's having drinks with him tonight.", 'meta': {'tokens': [['Well', ',', 'Rachel', "'s", 'having', 'drinks', 'with', 'him', 'tonight', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[2, 3, 'Rachel Green'], [7, 8, "Carl (Rachel's date)"]]]}}),
#  Utterance({'id': 's01_e24_c02_u056', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c02_u001', 'reply_to': 's01_e24_c02_u055', 'timestamp': None, 'text': "Yeah... I guess. I don'tI don't know. Alright, just... just give her this for me, OK?", 'meta': {'tokens': [['Yeah', '...'], ['I', 'guess', '.'], ['I', "don'tI", 'do', "n't", 'know', '.'], ['Alright', ',', 'just', '...'], ['just', 'give', 'her', 'this', 'for', 'me', ',', 'OK', '?']], 'transcript_with_note': "Yeah... I guess. I don'tI don't know. Alright, just... just give her this for me, OK? (gives Chandler a gift for Rachel)", 'tokens_with_note': [['Yeah', '...'], ['I', 'guess', '.'], ['I', "don'tI", 'do', "n't", 'know', '.'], ['Alright', ',', 'just', '...'], ['just', 'give', 'her', 'this', 'for', 'me', ',', 'OK', '?'], ['(', 'gives', 'Chandler', 'a', 'gift', 'for', 'Rachel', ')']], 'character_entities': [[], [[0, 1, '#GENERAL#']], [[0, 1, 'Ross Geller']], [], [[2, 3, 'Rachel Green'], [5, 6, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e24_c02_u058', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c02_u001', 'reply_to': 's01_e24_c02_u057', 'timestamp': None, 'text': 'I know.', 'meta': {'tokens': [['I', 'know', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e24_c04_u001', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c04_u001', 'reply_to': None, 'timestamp': None, 'text': '', 'meta': {'tokens': [], 'transcript_with_note': '(something in Chinese)', 'tokens_with_note': [['(', 'something', 'in', 'Chinese', ')']], 'character_entities': []}}),
#  Utterance({'id': 's01_e24_c04_u003', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c04_u001', 'reply_to': 's01_e24_c04_u002', 'timestamp': None, 'text': 'Ni-chou chi-ma!', 'meta': {'tokens': [['Ni', '-', 'chou', 'chi', '-', 'ma', '!']], 'transcript_with_note': 'Ni-chou chi-ma! (walks onto jetway)', 'tokens_with_note': [['Ni', '-', 'chou', 'chi', '-', 'ma', '!'], ['(', 'walks', 'onto', 'jetway', ')']], 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e24_c10_u003', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c10_u001', 'reply_to': 's01_e24_c10_u002', 'timestamp': None, 'text': "I can't believe you'd rather go out with him than me.", 'meta': {'tokens': [['I', 'ca', "n't", 'believe', 'you', "'d", 'rather', 'go', 'out', 'with', 'him', 'than', 'me', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller'], [4, 5, 'Rachel Green'], [10, 11, "Carl (Rachel's date)"], [12, 13, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e24_c10_u005', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c10_u001', 'reply_to': 's01_e24_c10_u004', 'timestamp': None, 'text': 'Fine, just stop thinking about me.', 'meta': {'tokens': [['Fine', ',', 'just', 'stop', 'thinking', 'about', 'me', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[6, 7, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e24_c10_u007', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c10_u001', 'reply_to': 's01_e24_c10_u006', 'timestamp': None, 'text': "Can't do it, can you?", 'meta': {'tokens': [['Ca', "n't", 'do', 'it', ',', 'can', 'you', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[6, 7, 'Rachel Green']]]}}),
#  Utterance({'id': 's01_e24_c10_u009', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c10_u001', 'reply_to': 's01_e24_c10_u008', 'timestamp': None, 'text': "I don't get it. What do you see in this guy, anyway?", 'meta': {'tokens': [['I', 'do', "n't", 'get', 'it', '.'], ['What', 'do', 'you', 'see', 'in', 'this', 'guy', ',', 'anyway', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller']], [[2, 3, 'Rachel Green'], [6, 7, "Carl (Rachel's date)"]]]}}),
#  Utterance({'id': 's01_e24_c10_u012', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c10_u001', 'reply_to': 's01_e24_c10_u011', 'timestamp': None, 'text': 'Rachel, come on. Give us a chance.', 'meta': {'tokens': [['Rachel', ',', 'come', 'on', '.'], ['Give', 'us', 'a', 'chance', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [[1, 2, 'Ross Geller', 'Rachel Green']]]}}),
#  Utterance({'id': 's01_e24_c10_u014', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c10_u001', 'reply_to': 's01_e24_c10_u013', 'timestamp': None, 'text': "No, no, no... why, because it might get weird for everyone else? Who cares about them. This is about us. Look, I-I've been in love with you since, like, the ninth grade.", 'meta': {'tokens': [['No', ',', 'no', ',', 'no', '.'], ['..'], ['why', ',', 'because', 'it', 'might', 'get', 'weird', 'for', 'everyone', 'else', '?'], ['Who', 'cares', 'about', 'them', '.'], ['This', 'is', 'about', 'us', '.'], ['Look', ',', 'I', '-', 'I', "'ve", 'been', 'in', 'love', 'with', 'you', 'since', ',', 'like', ',', 'the', 'ninth', 'grade', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [], [], [[3, 4, 'Monica Geller', 'Chandler Bing', 'Phoebe Buffay', 'Joey Tribbiani']], [[3, 4, 'Ross Geller', 'Rachel Green']], [[2, 3, 'Ross Geller'], [4, 5, 'Ross Geller'], [10, 11, 'Rachel Green']]]}}),
#  Utterance({'id': 's01_e24_c10_u016', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c10_u001', 'reply_to': 's01_e24_c10_u015', 'timestamp': None, 'text': 'I know.', 'meta': {'tokens': [['I', 'know', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[[0, 1, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e24_c10_u018', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c10_u001', 'reply_to': 's01_e24_c10_u017', 'timestamp': None, 'text': "Whoa, whoa, whoa. What makes you think we're gonna break up?", 'meta': {'tokens': [['Whoa', ',', 'whoa', ',', 'whoa', '.'], ['What', 'makes', 'you', 'think', 'we', "'re", 'gon', 'na', 'break', 'up', '?']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [[2, 3, 'Rachel Green'], [4, 5, 'Ross Geller', 'Rachel Green']]]}}),
#  Utterance({'id': 's01_e24_c10_u020', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c10_u001', 'reply_to': 's01_e24_c10_u019', 'timestamp': None, 'text': 'No. But... it only has to happen once. Look, you and I both know we are perfect for each other, right? I mean... so, the only question is... are you attracted to me?', 'meta': {'tokens': [['No', '.'], ['But', '...'], ['it', 'only', 'has', 'to', 'happen', 'once', '.'], ['Look', ',', 'you', 'and', 'I', 'both', 'know', 'we', 'are', 'perfect', 'for', 'each', 'other', ',', 'right', '?'], ['I', 'mean', '...'], ['so', ',', 'the', 'only', 'question', 'is', '...'], ['are', 'you', 'attracted', 'to', 'me', '?']], 'transcript_with_note': '(pause) No. But... it only has to happen once. Look, you and I both know we are perfect for each other, right? I mean... so, the only question is... are you attracted to me?', 'tokens_with_note': [['(', 'pause', ')', 'No', '.'], ['But', '...'], ['it', 'only', 'has', 'to', 'happen', 'once', '.'], ['Look', ',', 'you', 'and', 'I', 'both', 'know', 'we', 'are', 'perfect', 'for', 'each', 'other', ',', 'right', '?'], ['I', 'mean', '...'], ['so', ',', 'the', 'only', 'question', 'is', '...'], ['are', 'you', 'attracted', 'to', 'me', '?']], 'character_entities': [[], [], [], [[2, 3, 'Rachel Green'], [4, 5, 'Ross Geller'], [7, 8, 'Ross Geller', 'Rachel Green']], [[0, 1, 'Ross Geller']], [], [[1, 2, 'Rachel Green'], [4, 5, 'Ross Geller']]]}}),
#  Utterance({'id': 's01_e24_c10_u022', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c10_u001', 'reply_to': 's01_e24_c10_u021', 'timestamp': None, 'text': 'Well, start looking.', 'meta': {'tokens': [['Well', ',', 'start', 'looking', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e24_c11_u005', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c11_u001', 'reply_to': 's01_e24_c11_u004', 'timestamp': None, 'text': 'Oh, hey, hey, I got that.', 'meta': {'tokens': [['Oh', ',', 'hey', ',', 'hey', ',', 'I', 'got', 'that', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e24_c11_u008', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c11_u001', 'reply_to': 's01_e24_c11_u007', 'timestamp': None, 'text': 'No problem. I cannot wait for you to meet my friends.', 'meta': {'tokens': [['No', 'problem', '.'], ['I', 'can', 'not', 'wait', 'for', 'you', 'to', 'meet', 'my', 'friends', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], []]}}),
#  Utterance({'id': 's01_e24_c11_u010', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c11_u001', 'reply_to': 's01_e24_c11_u009', 'timestamp': None, 'text': 'Yeah.', 'meta': {'tokens': [['Yeah', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}}),
#  Utterance({'id': 's01_e24_c11_u012', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c11_u001', 'reply_to': 's01_e24_c11_u011', 'timestamp': None, 'text': 'No, no, they will. I just... uh...', 'meta': {'tokens': [['No', ',', 'no', ',', 'they', 'will', '.'], ['I', 'just', '...'], ['uh', '...']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[], [], []]}}),
#  Utterance({'id': 's01_e24_c11_u014', 'user': User([('name', 'Ross Geller')]), 'root': 's01_e24_c11_u001', 'reply_to': 's01_e24_c11_u013', 'timestamp': None, 'text': "Come on, they're gonna love you.", 'meta': {'tokens': [['Come', 'on', ',', 'they', "'re", 'gon', 'na', 'love', 'you', '.']], 'transcript_with_note': None, 'tokens_with_note': None, 'character_entities': [[]]}})]
